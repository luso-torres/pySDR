# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

Ts = 1000
t = [i for i in range(0,2*Ts)]
x = np.array([0]*Ts)
periods = 1
#y = np.zeros(Ts)
y = []
y = np.append(y,[1]*Ts)
y = np.append(y,np.zeros(Ts))
x =1/Ts*np.float64(t)
#x = 1/Ts*np.float64(t)*periods
#f = np.step(x)

F_fft = fft(y)
len(x)
#len(y)
plt.plot(x,y)

# %%
plt.plot(x,F_fft)
