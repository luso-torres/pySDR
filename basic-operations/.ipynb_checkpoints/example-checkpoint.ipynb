# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

Ts = 100
t = range(0,Ts)
x = np.array([0]*Ts)
periods = 10

for i in range(Ts):
    x[i] = i/Ts*2*periods*np.pi
f = np.cos(x)

F_fft = fft(f)
plt.plot(x,f)
#plt.plot(x,F_fft)
f
# Out:
# array([ 1.        ,  1.        ,  0.54030231,  0.54030231, -0.41614684,
#        -0.9899925 , -0.9899925 , -0.65364362,  0.28366219,  0.28366219,
#         0.96017029,  0.96017029,  0.75390225, -0.14550003, -0.14550003,
#        -0.91113026, -0.83907153, -0.83907153,  0.0044257 ,  0.0044257 ,
#         0.84385396,  0.90744678,  0.90744678,  0.13673722, -0.75968791,
#        -0.75968791, -0.95765948, -0.95765948, -0.27516334,  0.66031671,
#         0.66031671,  0.98870462,  0.40808206,  0.40808206, -0.54772926,
#        -0.54772926, -0.99996083, -0.53283302, -0.53283302,  0.42417901,
#         0.99120281,  0.99120281,  0.64691932, -0.29213881, -0.29213881,
#        -0.96260587, -0.96260587, -0.74805753,  0.15425145,  0.15425145,
#         0.91474236,  0.83422336,  0.83422336, -0.01327675, -0.01327675,
#        -0.84857027, -0.90369221, -0.90369221, -0.12796369,  0.76541405,
#         0.76541405,  0.95507364,  0.95507364,  0.26664293, -0.66693806,
# ...
